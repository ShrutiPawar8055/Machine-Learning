# %%
import pickle 
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
# assume user input
test_input2 = np.array([2,'male', 31.0, 0, 0, 10.5, 'S'], dtype=object).reshape(1,7)  

#reshape is used to convert the 1D array into a 2D array with 1 row and 7 columns.

# %%
pipe.predict(test_input2)
# Out:
# /home/shruti/anaconda3/envs/ml1/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/shruti/anaconda3/envs/ml1/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
