# %% [markdown]
# Read data

# %%
import pandas as pd

df = pd.read_csv("data.csv")

# %%
df
# Out:
#    CustomerID   Age  Annual_Income_k      City
# 0         101  23.0             50.0  New York
# 1         102  45.0             85.0     Paris
# 2         103   NaN             62.0  New York
# 3         104  31.0              NaN    London
# 4         105  22.0             45.0       NaN
# 5         106  54.0            120.0    London
# 6         107  38.0            350.0     Paris
